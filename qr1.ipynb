# %%
from inference_sdk import InferenceHTTPClient
import cv2 as cv
import matplotlib.pyplot as plt

# %%
CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="1LLHLsNgIkU8Fjad1Se3"
)

# %%
result = CLIENT.infer("C:\\Users\\nagar\\Desktop\\foviatech\\tasks\\dataset\\qr\\qr2.jpg", model_id="qrcode-chabr/1")
type(result)
# Out:
# dict

# %%
img = cv.imread("C:\\Users\\nagar\\Desktop\\foviatech\\tasks\\dataset\\qr\\qr2.jpg")
img.shape
# Out:
# (4080, 3072, 3)

# %%
plt.imshow(img)

# %%
result
# Out:
# {'time': 0.04320996599994942,
#  'image': {'width': 3072, 'height': 4080},
#  'predictions': [{'x': 1488.1640625,
#    'y': 2091.796875,
#    'width': 952.265625,
#    'height': 948.28125,
#    'confidence': 0.930370032787323,
#    'class': '0',
#    'class_id': 0,
#    'detection_id': '560aef37-c39e-4468-9145-785cafc685f9'}]}

# %%
predictions = result['predictions']
x = int(predictions[0]['x'])
y = int(predictions[0]['y'])
w = int(predictions[0]['width'])
h = int(predictions[0]['height'])
print(x, y, w, h)
# Out:
# 1488 2091 952 948

# %%
plt.imshow(img)

# %%
crop = img[y-int(h/2): y+int(h/2), x-int(w/2): x+int(w/2) ]

# %%
plt.imshow(crop)
